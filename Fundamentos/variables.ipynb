# %% [markdown]
# Variables, Entradas, Salidas

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# Declarando Variables

# %%
Edad= 25
print(Edad)
# Out:
# 25

# %%
nomnre = "Maria"
edad =17
estatura = 1.60
print("Mi nombre es", nomnre, "tengo", edad, "años y mido", estatura, "metros")
# Out:
# Mi nombre es Maria tengo 17 años y mido 1.6 metros

# %%
precioProductos = 150
print(type(precioProductos))
precioProductos = 1.3
print
# Out:
# <class 'int'>
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print("Ingrese su nombre")
nombre = input()
print("Hola", nombre, "bienvenido a Python desde cero")
# Out:
# Ingrese su nombre
# Hola  bienvenido a Python desde cero

# %%
nombre = "Maria"
edad =17
print("nombre:"+nombre)
print("edad:"+str(edad))
# Out:
# nombre:Maria
# edad:17
